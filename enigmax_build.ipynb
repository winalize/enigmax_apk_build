# %%
# !apt update -y && apt install -y openjdk-17-jdk autoconf automake libtool pkg-config python3-dev
# !pip install buildozer cython virtualenv
# !git clone https://github.com/winalize/enigmax_apk_build /content/app
# %cd /content/app
# !buildozer init
# !buildozer -v android debug
